# %%
print (" shivali college of engineering Dehradun")
print( " hello friends")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-66249c13ba8b> in <cell line: 1>()
# ----> 1 print (" shivali college of engineering Dehradun")
#       2 print( " hello friends")
#       3
#
# TypeError: 'str' object is not callable

# %%
# convert to string
xa = str (3)  # x will be '3'

# convert to integer
ya = int(3) # y will be 3
#convert to float
za = float(3)  # z will be 3.0

print(xa)
print(ya)
print(za)
print(type(xa))
print(type(ya))
print(type(za))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-b195174627a1> in <cell line: 9>()
#       7 za = float(3)  # z will be 3.0
#       8
# ----> 9 print(xa)
#      10 print(ya)
#      11 print(za)
#
# TypeError: 'str' object is not callable

# %%
x=1  # int
y=4.31 # float
z= 3j #complex

print(type(x))
print(type(y))
print(type(z))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e697ac66e0ed> in <cell line: 5>()
#       3 z= 3j #complex
#       4
# ----> 5 print(type(x))
#       6 print(type(y))
#       7 print(type(z))
#
# TypeError: 'str' object is not callable

# %%
aeree= 10
b=20
c= float(a)
print(type(aeree))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-ddb27a794183> in <cell line: 4>()
#       2 b=20
#       3 c= float(a)
# ----> 4 print(type(aeree))
#
# TypeError: 'str' object is not callable

# %%
import random

# %%
aeree= 10
b=20
c= float(a)
print(type(aeree))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-ddb27a794183> in <cell line: 4>()
#       2 b=20
#       3 c= float(a)
# ----> 4 print(type(aeree))
#
# TypeError: 'str' object is not callable
