# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('dark_background')

# %%
df=pd.read_csv("/content/zomato.csv",encoding="latin1")
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df[df["Restaurant Name"]=="India"]
# Out:
# Empty DataFrame
# Columns: [Restaurant ID, Restaurant Name, Country Code, City, Address, Locality, Locality Verbose, Longitude, Latitude, Cuisines, Average Cost for two, Currency, Has Table booking, Has Online delivery, Is delivering now, Switch to order menu, Price range, Aggregate rating, Rating color, Rating text, Votes]
# Index: []
#
# [0 rows x 21 columns]

# %%
df[df['City']=='Ghaziabad']['Restaurant Name']
# Out:
# 1116    Chaudhary Ke Mashhoor Paranthe
# 1117                     Thakur Bakers
# 1118                         FoodByMom
# 1119                         Mr. Brown
# 1120                   Mitalis Kitchen
# 1121                     The Big Scoop
# 1122                     9 Mars Lounge
# 1123                           Barista
# 1124                    Baskin Robbins
# 1125                       Burger King
# 1126                   Cafe Coffee Day
# 1127                   Chinese X'Press
# 1128                             Cinch
# 1129                      Costa Coffee
# 1130                    Domino's Pizza
# 1131                      Dosa X'press
# 1132                      Kebab Xpress
# 1133                      Let's Noodle
# 1134                        McDonald's
# 1135                           Mx Corn
# 1136                    Dunkin' Donuts
# 1137                        Haldiram's
# 1138                     Pind Balluchi
# 1139                  Maini Restaurant
# ...

# %%
df_India=df[df[df["Restaurant Name"]=="India"]]

# %%
xyz=df_India.to_csv("India.csv",index=True)

# %%
df[df ['Rating text']=='Excellent']['City'].value_counts().head(5).plot(kind='bar')
# Out:
# <Axes: xlabel='City'>

# %%
df[df['City']=='Dehradun']['Rating text'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Rating text'>

# %%
df3=pd.merge(df,df)#merge data set
df3
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...
