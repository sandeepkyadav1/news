# %%
x=1
y=4.31
z=3j
print(type(x))
print(type(y))
print(type(z))
x = 1
y = 5594247324536
z = -53459342

print(type(x,y,z))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'complex'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2dd258d0e19b> in <cell line: 11>()
#       9 z = -53459342
#      10
# ---> 11 print(type(x,y,z))
#
# TypeError: type.__new__() argument 1 must be str, not int
